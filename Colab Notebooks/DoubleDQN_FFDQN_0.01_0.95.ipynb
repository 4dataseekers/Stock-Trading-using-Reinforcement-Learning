# %% [markdown]
# # Install packages

# %%
# !pip install ptan
# !pip install tensorboardx
# Out:
# ...
#      |████████████████████████████████| 773.1MB 22kB/s
# ...
#   Created wheel for ptan: filename=ptan-0.6-cp36-none-any.whl size=23501 sha256=9f3fb06d84a7c8554c644f4aa6c8502c9a4e287917d1459336babd7001e95981
#   Stored in directory: /root/.cache/pip/wheels/f0/4b/2f/9a45fd39b0a614a2716bc6128a7f1adb4647f323a2d90783f2
# Successfully built ptan
# ERROR: torchvision 0.4.2 has requirement torch==1.3.1, but you'll have torch 1.3.0 which is incompatible.
# ...
#   Found existing installation: torch 1.3.1
#     Uninstalling torch-1.3.1:
#       Successfully uninstalled torch-1.3.1
# ...
#      |████████████████████████████████| 194kB 3.4MB/s
# ...

# %% [markdown]
# # Check if CUDA is available

# %%
import torch
print(torch.__version__)
torch.cuda.is_available()
# Out:
# 1.3.0
# True

# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Goto the File path

# %%
cd '/content/drive/Shared drives/Reinforcement Learning/Sithara'
# Out:
# /content/drive/Shared drives/Reinforcement Learning/Sithara

# %% [markdown]
# # Run the Train Model file with desired parameters
#
# Make changes for dataset, saves and runs folders in train_model.py

# %%
# !python train_DQNDouble.py -r "/DoubleDQN_FFDQN_0.01_0.95" --cuda --double --learningrate 0.01 --gamma 0.95
# Out:
# cuda
# 0.95
# 0.01
# True
# /content/drive/Shared drives/Reinforcement Learning/Sithara/saves
# /DoubleDQN_FFDQN_0.01_0.95
# /content/drive/Shared drives/Reinforcement Learning/Sithara/saves/DoubleDQN_FFDQN_0.01_0.95
# here
# /content/drive/Shared drives/Reinforcement Learning/Sithara/data/YNDX_160101_161231.csv
# Reading /content/drive/Shared drives/Reinforcement Learning/Sithara/data/YNDX_160101_161231.csv
# Read done, got 131542 rows, 99752 filtered, 0 open prices adjusted
# Reading /content/drive/Shared drives/Reinforcement Learning/Sithara/data/YNDX_150101_151231.csv
# Read done, got 130566 rows, 104412 filtered, 0 open prices adjusted
# 671: done 100 games, mean reward -0.263, mean steps 6.70, speed 1521.23 f/s, eps 1.00
# 1263: done 200 games, mean reward -0.238, mean steps 6.31, speed 1515.31 f/s, eps 1.00
# 1854: done 300 games, mean reward -0.208, mean steps 6.18, speed 1422.75 f/s, eps 1.00
# ...

# %% [markdown]
# # Create Plots for change in profit overtime --- WE CAN DO THIS LATER USING THE SAVED LOGS
#
# Make changes for saving the plot at specific path

# %%
#!python run_model.py -d data/YNDX_160101_161231.csv -m 'saves/--run Simple FFDQN LR0.01/mean_val-0.013.data' -b 10 -n test

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %% [markdown]
# # Load Tensorboard to view the training
